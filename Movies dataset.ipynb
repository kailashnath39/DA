# %%
from google.colab import drive
drive.mount("\content\drive")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-95b1717e5c81> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount("\content\drive")
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     257
#     258   while True:
# --> 259     case = d.expect([
#     260         success,
#     261         prompt,
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(
    '/content/contentdrive/MyDrive/semester files/semester-5/DA/LABCYCLE/DATASETS/Adidas_USSales_Datasets_8thquestion.csv'
    )
header=np.array(data.loc[3,:])
data.drop(index = [0,1,2,3],columns=['Unnamed: 0'],inplace = True)
data.head()
data.set_index(range(0,data.count()))
# dfa.pop(0)
# dfa
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-70d53d8d2447> in <cell line: 7>()
#       5 data.drop(index = [0,1,2,3],columns=['Unnamed: 0'],inplace = True)
#       6 data.head()
# ----> 7 data.set_index(range(0,data.count()))
#       8 # dfa.pop(0)
#       9 # dfa
#
# TypeError: 'Series' object cannot be interpreted as an integer

# %%
data.tail()
# Out:
#       Unnamed: 0   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4     Unnamed: 5  \
# 9647         NaN  Foot Locker    1185732  1/24/2021  Northeast  New Hampshire
# 9648         NaN  Foot Locker    1185732  1/24/2021  Northeast  New Hampshire
# 9649         NaN  Foot Locker    1185732  2/22/2021  Northeast  New Hampshire
# 9650         NaN  Foot Locker    1185732  2/22/2021  Northeast  New Hampshire
# 9651         NaN  Foot Locker    1185732  2/22/2021  Northeast  New Hampshire
#
#       Unnamed: 6               Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 9647  Manchester            Men's Apparel    $50.00          64     $3,200
# 9648  Manchester          Women's Apparel    $41.00         105     $4,305
# 9649  Manchester    Men's Street Footwear    $41.00         184     $7,544
# 9650  Manchester  Men's Athletic Footwear    $42.00          70     $2,940
# 9651  Manchester  Women's Street Footwear    $29.00          83     $2,407
#
#      Unnamed: 11 Unnamed: 12 Unnamed: 13
# ...
